# %%
#Juan David Galan Vargas- 202111470

#Simulación de la trayectoria del sistema

# %%
import time
import numpy as np
import scipy as sci
import scipy.integrate as integrate
import sympy as sym
from sympy import symbols
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation
import math as m
plt.style.use('dark_background')

# %%
from matplotlib import rc
rc("animation", html = "jshtml")
sym.init_printing()
#matplotlib.rcParams['animation.embed_limit'] = 2**128

# %%
#Parametros
#Velocidad angular
w= 0.1*m.pi
#Posicion inicial
r_0=0.01
r=[]
#Tiempo (20 segundos)
t=np.linspace(0,20,100)
#trayectoria
phy=w*t
for i in phy:
    r.append(r_0*m.cosh(i))
plt.polar(phy, r)
plt.show()

# %%
#Parametros
#Velocidad angular
w= m.pi
#Posicion inicial
r_0=0.01
r=[]
#Tiempo
t=np.linspace(0,20,200)
#trayectoria
phy=w*t
for i in phy:
    r.append(r_0*m.cosh(i))
plt.polar(phy, r)
plt.show()
